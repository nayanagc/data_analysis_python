# %%
import requests
import pandas as pd

# %%
page = requests.get('http://api.weatherapi.com/v1/current.json?key=1e85d63222be4b55b4085940252003&q=Tumkur')

# %%
print(page)#page response
# Out:
# <Response [200]>

# %%
result=page.json()
print(result)
# Out:
# {'location': {'name': 'Tumkur', 'region': 'Karnataka', 'country': 'India', 'lat': 13.3422, 'lon': 77.1017, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1742462072, 'localtime': '2025-03-20 14:44'}, 'current': {'last_updated_epoch': 1742461200, 'last_updated': '2025-03-20 14:30', 'temp_c': 34.6, 'temp_f': 94.2, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 9.4, 'wind_kph': 15.1, 'wind_degree': 113, 'wind_dir': 'ESE', 'pressure_mb': 1011.0, 'pressure_in': 29.85, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 18, 'cloud': 4, 'feelslike_c': 32.7, 'feelslike_f': 90.8, 'windchill_c': 34.6, 'windchill_f': 94.2, 'heatindex_c': 32.7, 'heatindex_f': 90.8, 'dewpoint_c': 6.6, 'dewpoint_f': 43.9, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 9.2, 'gust_mph': 10.8, 'gust_kph': 17.4}}

# %%
n1=pd.DataFrame(result)
n1.head()
# Out:
#           location current
# name        Tumkur     NaN
# region   Karnataka     NaN
# country      India     NaN
# lat        13.3422     NaN
# lon        77.1017     NaN

# %%
page1 = requests.get('http://api.weatherapi.com/v1/forecast.json?key=1e85d63222be4b55b4085940252003&q=07112&days=7')

# %%
print(page1)
# Out:
# <Response [200]>

# %%
result1=page1.json()
print(result1)
# Out:
# {'location': {'name': 'Newark', 'region': 'New Jersey', 'country': 'USA', 'lat': 40.7107009887695, 'lon': -74.2130966186523, 'tz_id': 'America/New_York', 'localtime_epoch': 1742462635, 'localtime': '2025-03-20 05:23'}, 'current': {'last_updated_epoch': 1742462100, 'last_updated': '2025-03-20 05:15', 'temp_c': 6.1, 'temp_f': 43.0, 'is_day': 0, 'condition': {'text': 'Mist', 'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png', 'code': 1030}, 'wind_mph': 8.1, 'wind_kph': 13.0, 'wind_degree': 132, 'wind_dir': 'SE', 'pressure_mb': 1013.0, 'pressure_in': 29.91, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 89, 'cloud': 100, 'feelslike_c': 3.4, 'feelslike_f': 38.2, 'windchill_c': 3.5, 'windchill_f': 38.3, 'heatindex_c': 5.8, 'heatindex_f': 42.5, 'dewpoint_c': 5.4, 'dewpoint_f': 41.7, 'vis_km': 0.8, 'vis_miles': 0.0, 'uv': 0.0, 'gust_mph': 11.4, 'gust_kph': 18.4}, 'forecast': {'forecastday': [{'date': '2025-03-20', 'date_epoch': 1742428800, 'day': {'maxtemp_c': 10.2, 'maxtemp_f': 50.
# ...

# %%
n2=pd.DataFrame(result1)
n2.head()
# Out:
#            location current forecast
# name         Newark     NaN      NaN
# region   New Jersey     NaN      NaN
# country         USA     NaN      NaN
# lat       40.710701     NaN      NaN
# lon      -74.213097     NaN      NaN

# %%
page0 = requests.get('http://api.coincap.io/v2/assets/bitcoin')

# %%
print(page0)
# Out:
# <Response [200]>

# %%
result0=page0.json()
print(result0)
# Out:
# {'data': {'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC', 'name': 'Bitcoin', 'supply': '19839365.0000000000000000', 'maxSupply': '21000000.0000000000000000', 'marketCapUsd': '1706241760412.3130528488747730', 'volumeUsd24Hr': '10173204000.7721397007467311', 'priceUsd': '86002.8413415607330602', 'changePercent24Hr': '2.9533726942887002', 'vwap24Hr': '85201.0651284456121972', 'explorer': 'https://blockchain.info/'}, 'timestamp': 1742463795097}

# %%
import pandas as pd 
n=pd.DataFrame(result0)
n.head()
# Out:
#                                              data      timestamp
# changePercent24Hr              2.9533726942887002  1742463795097
# explorer                 https://blockchain.info/  1742463795097
# id                                        bitcoin  1742463795097
# marketCapUsd       1706241760412.3130528488747730  1742463795097
# maxSupply               21000000.0000000000000000  1742463795097

# %%
n.to_csv(r"C:\Users\DELL\Downloads\my_python\result0.csv")

# %%
page_1 = requests.get('http://api.coincap.io/v2/assets')

# %%
print(page_1)
# Out:
# <Response [200]>

# %%
result_1=page_1.json()
print(result_1)
# Out:
# {'data': [{'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC', 'name': 'Bitcoin', 'supply': '19839365.0000000000000000', 'maxSupply': '21000000.0000000000000000', 'marketCapUsd': '1704955514229.8536583614825300', 'volumeUsd24Hr': '10140624530.3458942477910495', 'priceUsd': '85938.0083097343921220', 'changePercent24Hr': '2.9939351116256912', 'vwap24Hr': '85201.0651284456121972', 'explorer': 'https://blockchain.info/'}, {'id': 'ethereum', 'rank': '2', 'symbol': 'ETH', 'name': 'Ethereum', 'supply': '120629195.4269564900000000', 'maxSupply': None, 'marketCapUsd': '242111101587.1799842856242144', 'volumeUsd24Hr': '6622944848.4808813207588759', 'priceUsd': '2007.0688586643466302', 'changePercent24Hr': '3.4417480343071294', 'vwap24Hr': '2023.0357853491439004', 'explorer': 'https://etherscan.io/'}, {'id': 'xrp', 'rank': '3', 'symbol': 'XRP', 'name': 'XRP', 'supply': '58108919817.0000000000000000', 'maxSupply': '100000000000.0000000000000000', 'marketCapUsd': '145761026736.6174415875141228', 'volu
# ...

# %%
cd=result_1['data']
mydata=pd.DataFrame(cd)
mydata.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19839365.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120629195.4269564900000000
# 2           xrp    3    XRP       XRP   58108919817.0000000000000000
# 3        tether    4   USDT    Tether  143653509034.0653000000000000
# 4  binance-coin    5    BNB       BNB     144006830.0000000000000000
#
#                        maxSupply                    marketCapUsd  \
# 0      21000000.0000000000000000  1704955514229.8536583614825300
# 1                           None   242111101587.1799842856242144
# 2  100000000000.0000000000000000   145761026736.6174415875141228
# 3                           None   143740135265.1651833230852544
# 4     144006830.0000000000000000    91541242235.4067090238004010
#
#                   volumeUsd24Hr                priceUsd   changePercent24Hr  \
# 0  10140624530.3458942477910495  85938.0083097343921220  2.9939351116256912
# ...

# %%
mydata.to_csv(r"C:\Users\DELL\Downloads\my_python\cd.csv")

# %%
mf=pd.read_csv(r"C:\Users\DELL\Downloads\my_python\cd.csv")

# %%
mf.head()
# Out:
#    Unnamed: 0            id  rank symbol      name        supply  \
# 0           0       bitcoin     1    BTC   Bitcoin  1.983936e+07
# 1           1      ethereum     2    ETH  Ethereum  1.206292e+08
# 2           2           xrp     3    XRP       XRP  5.810892e+10
# 3           3        tether     4   USDT    Tether  1.436535e+11
# 4           4  binance-coin     5    BNB       BNB  1.440068e+08
#
#       maxSupply  marketCapUsd  volumeUsd24Hr      priceUsd  changePercent24Hr  \
# 0  2.100000e+07  1.704956e+12   1.014062e+10  85938.008310           2.993935
# 1           NaN  2.421111e+11   6.622945e+09   2007.068859           3.441748
# 2  1.000000e+11  1.457610e+11   3.362940e+09      2.508411           8.607738
# 3           NaN  1.437401e+11   2.463389e+10      1.000603           0.149654
# 4  1.440068e+08  9.154124e+10   5.531811e+08    635.672921           3.247602
#
#        vwap24Hr                                           explorer
# ...

# %%
import seaborn as sns 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
mf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         100 non-null    int64
#  1   id                 100 non-null    object
#  2   rank               100 non-null    int64
#  3   symbol             100 non-null    object
#  4   name               100 non-null    object
#  5   supply             100 non-null    float64
#  6   maxSupply          44 non-null     float64
#  7   marketCapUsd       100 non-null    float64
#  8   volumeUsd24Hr      100 non-null    float64
#  9   priceUsd           100 non-null    float64
#  10  changePercent24Hr  100 non-null    float64
#  11  vwap24Hr           98 non-null     float64
#  12  explorer           89 non-null     object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 10.3+ KB

# %%
mf.isnull().sum()
# Out:
# Unnamed: 0            0
# id                    0
# rank                  0
# symbol                0
# name                  0
# supply                0
# maxSupply            56
# marketCapUsd          0
# volumeUsd24Hr         0
# priceUsd              0
# changePercent24Hr     0
# vwap24Hr              2
# explorer             11
# dtype: int64

# %%
mf.dropna(inplace=True)
mf.isnull().sum()
# Out:
# Unnamed: 0           0
# id                   0
# rank                 0
# symbol               0
# name                 0
# supply               0
# maxSupply            0
# marketCapUsd         0
# volumeUsd24Hr        0
# priceUsd             0
# changePercent24Hr    0
# vwap24Hr             0
# explorer             0
# dtype: int64

# %%
mf.describe(include='all')
# Out:
#         Unnamed: 0       id       rank symbol     name        supply  \
# count    40.000000       40  40.000000     40       40  4.000000e+01
# unique         NaN       40        NaN     40       40           NaN
# top            NaN  bitcoin        NaN    BTC  Bitcoin           NaN
# freq           NaN        1        NaN      1        1           NaN
# mean     46.375000      NaN  47.375000    NaN      NaN  2.550103e+13
# std      29.211595      NaN  29.211595    NaN      NaN  1.130327e+14
# min       0.000000      NaN   1.000000    NaN      NaN  8.480744e+05
# 25%      19.750000      NaN  20.750000    NaN      NaN  1.493931e+08
# 50%      42.500000      NaN  43.500000    NaN      NaN  1.409425e+09
# 75%      67.250000      NaN  68.250000    NaN      NaN  2.710419e+10
# max      98.000000      NaN  99.000000    NaN      NaN  5.892529e+14
#
#            maxSupply  marketCapUsd  volumeUsd24Hr      priceUsd  \
# count   4.000000e+01  4.000000e+01   4.000000e+01     40.000000
# ...

# %%
plt.figure(figsize=(6,5))
sns.histplot(mf['rank'],kde=True,bins=15)
plt.title('distribution of the rank ')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
nmf=mf.select_dtypes(include=['number'])
nmf.head()
# Out:
#     Unnamed: 0  rank        supply     maxSupply  marketCapUsd  volumeUsd24Hr  \
# 0            0     1  1.983936e+07  2.100000e+07  1.704956e+12   1.014062e+10
# 2            2     3  5.810892e+10  1.000000e+11  1.457610e+11   3.362940e+09
# 4            4     5  1.440068e+08  1.440068e+08  9.154124e+10   5.531811e+08
# 8            8     9  3.523480e+10  4.500000e+10  2.583631e+10   5.074687e+08
# 14          14    15  2.476378e+09  5.047559e+09  9.021006e+09   7.802840e+07
#
#         priceUsd  changePercent24Hr      vwap24Hr
# 0   85938.008310           2.993935  85201.065128
# 2       2.508411           8.607738      2.489808
# 4     635.672921           3.247602    617.609169
# 8       0.733261           2.599788      0.732204
# 14      3.642822           1.638530      3.654987

# %%
subset = mf.loc[2:50, ['priceUsd', 'name']]
print(subset.head(10))
# Out:
#       priceUsd       name
# 2     2.508411        XRP
# 4   635.672921        BNB
# 8     0.733261    Cardano
# 14    3.642822    Toncoin
# 15    0.287798    Stellar
# 16    0.194405     Hedera
# 17   19.096878  Avalanche
# 18    2.478497        Sui
# 19    0.000013  Shiba Inu
# 20   92.526402   Litecoin

# %%
plt.figure(figsize=(14,5))
plt.scatter(subset['name'],subset['priceUsd'],color='k',label='price',marker="D")
plt.xlabel("name")
plt.ylabel("price")
plt.legend()

# %% [markdown]
# price is less than 2usb and create a scatter plot

# %%
q=mf[mf['priceUsd']<2]
q
# Out:
#     Unnamed: 0                id  rank symbol  \
# 8            8           cardano     9    ADA
# 15          15           stellar    16    XLM
# 16          16  hedera-hashgraph    17   HBAR
# 19          19         shiba-inu    20   SHIB
# 32          32              pepe    33   PEPE
# 39          39           vechain    40    VET
# 42          42             kaspa    43    KAS
# 43          43   crypto-com-coin    44    CRO
# 51          51          algorand    52   ALGO
# 53          53            fantom    54      S
# 54          54           jupiter    55    JUP
# 57          57             fetch    58    FET
# 64          64            stacks    65    STX
# 68          68             theta    69  THETA
# 71          71               eos    72    EOS
# 75          75              gala    76   GALA
# 91          91           telcoin    92    TEL
# 92          92         floki-inu    93  FLOKI
# 94          94   curve-dao-token    95    CRV
# ...

# %%
plt.figure(figsize=(14,5))
plt.scatter(q['name'],q['priceUsd'],color='k',label='price',marker="D")
plt.xlabel("name")
plt.ylabel("price")
plt.legend()
